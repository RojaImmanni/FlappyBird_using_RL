# %% [markdown]
# ## In this notebook, we are going to train a random agent as a baseline model

# %% [markdown]
# #### Import the environment and the agent

# %%
from Game.environment import *
from Agents.Baseline_agent import *

# %% [markdown]
# #### Create a baseline agent and train for 50,000 iterations and save the scores

# %%
agent = Baseline_Agent(actions = [0, 1])
agent.train(50000, 100)
# Out:
# Iter:  0
# Iter:  250
# Max Score on Evaluation:  77
# Iter:  500
# Iter:  750
# Max Score on Evaluation:  75
# Iter:  1000
# Iter:  1250
# Max Score on Evaluation:  62
# Iter:  1500
# Iter:  1750
# Max Score on Evaluation:  86
# Iter:  2000
# Iter:  2250
# Max Score on Evaluation:  62
# Iter:  2500
# Iter:  2750
# Max Score on Evaluation:  69
# Iter:  3000
# Iter:  3250
# Max Score on Evaluation:  69
# Iter:  3500
# Iter:  3750
# Max Score on Evaluation:  76
# Iter:  4000
# Iter:  4250
# Max Score on Evaluation:  66
# Iter:  4500
# Iter:  4750
# Max Score on Evaluation:  69
# Iter:  5000
# Iter:  5250
# Max Score on Evaluation:  63
# Iter:  5500
# Iter:  5750
# Max Score on Evaluation:  64
# Iter:  6000
# Iter:  6250
# Max Score on Evaluation:  61
# Iter:  6500
# Iter:  6750
# Max Score on Evaluation:  67
# Iter:  7000
# Iter:  7250
# Max Score on Evaluation:  70
# Iter:  7500
# Iter:  7750
# Max Score on Evaluation:  67
# Iter:  8000
# Iter:  8250
# Max Score on Evaluation:  69
# ...

# %% [markdown]
# #### Look at the results.

# %%
scores = pd.read_csv("Scores/baseline.csv", index_col= 0)

# %%
scores.plot()

# %% [markdown]
# The values ranged from 60-95. The average of the max score hasn't gone up which means that there was hardly any useful training with the random agent
